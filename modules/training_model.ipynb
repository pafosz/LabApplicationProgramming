# %%
import pandas as pd
import plot_graph as pg

path = r'C:\Users\Admin\Desktop\University\2 cours\3 semester\PP\LabAppProg\LabApplicationProgramming\datasets\dataset.csv'
df = pd.read_csv(path)

# %%
import torch

# %%
mean_val = df['data'].median()
mean_val
# Out:
# 32.630399999999995
